# %%
#Importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### DATA LOADING

# %%
df = pd.read_csv('Data/Raw/logistics_dataset.csv')
# Out:
# Dataset loaded with 3204 records and 23 columns.

# %% [markdown]
# ### GET FAMILIAR WITH THE DATA

# %%
# NO. OF RECORDS AND FEATURES AVAILABLE
print(f"Dataset loaded with {df.shape[0]} records and {df.shape[1]} columns.")
# Out:
# Dataset loaded with 3204 records and 23 columns.

# %%
#FIRST 5 RECORDS
df.head()
# Out:
#     item_id    category  stock_level  reorder_point  reorder_frequency_days  \
# 0  ITM10000      Pharma          283             21                       4
# 1  ITM10001  Automotive          301             52                       9
# 2  ITM10002   Groceries          132             60                      11
# 3  ITM10003  Automotive          346             46                      13
# 4  ITM10004  Automotive           49             55                       4
#
#    lead_time_days  daily_demand  demand_std_dev  item_popularity_score  \
# 0               4         49.85            1.56                   0.43
# 1               6         23.34            2.55                   0.69
# 2               8         37.69            3.15                   0.62
# 3               5         33.69            2.79                   0.21
# 4               6         49.58            5.23                   0.31
#
#   storage_location_id  ... unit_price  holding_cost_per_unit_day  \
# ...

# %%
# BASIC INFORMATION
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3204 entries, 0 to 3203
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_id                    3204 non-null   object
#  1   category                   3204 non-null   object
#  2   stock_level                3204 non-null   int64
#  3   reorder_point              3204 non-null   int64
#  4   reorder_frequency_days     3204 non-null   int64
#  5   lead_time_days             3204 non-null   int64
#  6   daily_demand               3204 non-null   float64
#  7   demand_std_dev             3204 non-null   float64
#  8   item_popularity_score      3204 non-null   float64
#  9   storage_location_id        3204 non-null   object
#  10  zone                       3204 non-null   object
#  11  picking_time_seconds       3204 non-null   int64
#  12  handling_cost_per_unit     3204 non-null   float64
# ...

# %%
# The Dtype of 'last_restock_date' is Object, So we change them to Date Type
df['last_restock_date'] = pd.to_datetime(df['last_restock_date'], format='%d/%m/%Y')

# %%
#Recheck the datatype of 'last_restock_date' 
print(df['last_restock_date'].dtypes)
# Out:
# datetime64[ns]

# %%
# Satistical overview of our data

df.describe(include='all').T
# Out:
#                             count unique       top freq  \
# item_id                      3204   3204  ITM13203    1
# category                     3204      5    Pharma  660
# stock_level                3204.0    NaN       NaN  NaN
# reorder_point              3204.0    NaN       NaN  NaN
# reorder_frequency_days     3204.0    NaN       NaN  NaN
# lead_time_days             3204.0    NaN       NaN  NaN
# daily_demand               3204.0    NaN       NaN  NaN
# demand_std_dev             3204.0    NaN       NaN  NaN
# item_popularity_score      3204.0    NaN       NaN  NaN
# storage_location_id          3204    100       L57   41
# zone                         3204      4         D  833
# picking_time_seconds       3204.0    NaN       NaN  NaN
# handling_cost_per_unit     3204.0    NaN       NaN  NaN
# unit_price                 3204.0    NaN       NaN  NaN
# holding_cost_per_unit_day  3204.0    NaN       NaN  NaN
# stockout_count_last_month  3204.0    NaN       NaN  NaN
# ...

# %%
# Checking missing values
print(df.isnull().sum())
# Out:
# item_id                      0
# category                     0
# stock_level                  0
# reorder_point                0
# reorder_frequency_days       0
# lead_time_days               0
# daily_demand                 0
# demand_std_dev               0
# item_popularity_score        0
# storage_location_id          0
# zone                         0
# picking_time_seconds         0
# handling_cost_per_unit       0
# unit_price                   0
# holding_cost_per_unit_day    0
# stockout_count_last_month    0
# order_fulfillment_rate       0
# total_orders_last_month      0
# turnover_ratio               0
# layout_efficiency_score      0
# last_restock_date            0
# forecasted_demand_next_7d    0
# KPI_score                    0
# dtype: int64

# %%
#Checking Duplicate records
print(f"Duplicates: {df.duplicated().sum()}")
# Out:
# Duplicates: 0
